# %% [markdown]
# #### Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a,b = map(float, input().split())
s = a*b
c = (a+b)*2
print(f"Dien tich la {s} va chu vi la {c}")
# Out:
# Dien tich la 6.0 va chu vi la 10.0

# %% [markdown]
# #### Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
r = float(input())
s = 3.14 * r**2
c = 2*3.14*r
print(f"dien rich hinh tron la {s}, chu vi hinh tron la {c}")

# %% [markdown]
# #### Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
a, b, c = map(float, input().split())
if a + b > c and a + c > b and b + c > a and a > 0 and b > 0 and c > 0:
    if a == b == c:
        print("La tam giac deu")
    elif a == b or a == c or b == c:
        print("La tam giac can")
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or c**2 + b**2 == b**2:
        print("La tam giac vuong")
    else:
        print("La tam giac thuong")
    p = (a+b+c)/2
    s = (p*(p-a)*(p-b)*(p-c))**0.5
    c = a + b + c
    print(f"Dien tich tam giac la {s}, chu vi tam giac la {c}")
else:
    print("Khong phai tam giac")
# Out:
# Khong phai tam giac

# %% [markdown]
# #### Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b = map(float, input().split())
if a == 0:
    print("Phuong trinh vo nghiem")
else:
    x = (-b)/a
    print(f"{x}")
# Out:
# -1.5

# %% [markdown]
# #### Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a, b, c = map(float, input().split())
d = b**2 - 4*a*c
if a == 0:
    print("Khong phai phuong trinh bac 2")
elif d > 0:
    print( f"Nghiem phuong trinh la x = {(-b-(d**0.5))/(2*a)} va x = {(-b+(d**0.5))/(2*a)}")
elif d == 0:
    print(f"Nghiem phuong trinh la x = {(-b)/(2*a)}")
else:
    print("Phuong trinh vo nghiem")
# Out:
# Nghiem phuong trinh la x = -1.0

# %% [markdown]
# #### Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d = map(float, input().split())
print(f"So lon nhat la {max(a, b, c, d)}")
# Out:
# So lon nhat la 123.0

# %% [markdown]
# #### Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d = map(float, input().split())
print(f"So nho nhat la {min(a, b, c, d)}")
# Out:
# So nho nhat la 1.0

# %% [markdown]
# #### Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %% [markdown]
# #### Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x = int(input())
h = x//3600
phut = (x%3600)//60
giay = (x%3600)%60
print(f"{h} gio, {phut} phut, {giay} giay")
# Out:
# 1 gio, 1 phut, 5 giay

# %% [markdown]
# #### Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a, b = map(float, input("Nhap toa do tam duong tron").split())
r = float(input("Nhap ban kinh"))
x, y = map(float, input("Nhap toa do diem A").split())
if (x - a)**2 + (y - b)**2 == r**2:
    print("Diem A thuoc duong tron tren")
else:
    print("Diem A khong thuoc duong tron tren")
# Out:
# Diem A khong thuoc duong tron tren

# %% [markdown]
# #### Bài 11: Tính x^y (Với x, y là số thực).

# %%
x, y = map(float, input().split())
print(f"Gia tri cua x^y la {x**y}")
# Out:
# Gia tri cua x^y la 0.0
